# %%
import pandas as pd

# %%
data = pd.read_excel(
    r"C:\Users\DELL\OneDrive\Desktop\Provincial-Inpatient-Admission-Forecasting-in-Canada\data\hospital-childbirth-1995-2023-supplementary-data-tables-en.xlsx"
)
